# %% [markdown]
# # Fittare i picchi

# %% [markdown]
# 399 punti tra 600 e 900 nm

# %%
from varshni_subroutines import *

import warnings
warnings.filterwarnings("ignore", category=pd.errors.ParserWarning)

# %% [markdown]
# ## Parte 0: nomi file e funzioni

# %%
# Nomi file 
# orangeF sta per filtro arancione
campione_1 = 'campione_1/C240830_'
campione_2 = 'campione_2/C240920_'
d_o_emi = ['0', '0o5', '1', '1o5', '2', '2o5', '3']#, '3o5']
d_o_ass = ['0', '1']
arr_temperatura = [15, 30, 45, 70, 100, 150]

# %% [markdown]
# ## CAMPIONE 1 REFERENCE

# %%
# Per ciascuno dei due valori di ass

raccoglitore_1 = {
    'ass=0': {
        'emi=0o5':  [],
        'emi=1':    [],
        'emi=1o5':  [],
        'emi=2':    [],
        'emi=2o5':  [],
        'emi=3':    []
    },
    'ass=1': []
}

for ass in d_o_ass:
    emi_list = d_o_emi[1:] if ass == '0' else ['0']  # Per ass=1 usa solo emi='0'
    
    # Per ciascuno degli emi > 0 se ass=0, solo emi=0 se ass=1
    for emi in emi_list:
        arr_energia = []

        # Ciclo sulla temperatura
        for temp in arr_temperatura:
            try:
                nome_file = build_name(campione_1, emi, ass, temp)
                asse_x, asse_y = leggi_file(nome_file)
                print(min(asse_x), ',', max(asse_x))
            except FileNotFoundError:
                print(f"File non trovato: {nome_file}")
                continue
            
            picchi = find_peak_in_regions (asse_x, asse_y)
            
            fit_result = fit_gaussiani (asse_x, asse_y, picchi, emi, ass, temp)
            
            if ass == '1':
                raccoglitore_1['ass=1'].append(fit_result)
            else:
                raccoglitore_1['ass=0']['emi='+emi].append(fit_result)
# Out:
# 600.364 , 899.946
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=12042.78, mu=712.04, sigma=5.86
#   Gaussiana 2: a=89.32, mu=753.41, sigma=27611.62
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=40070.21, mu=818.13, sigma=4.63
# 600.364 , 899.946
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=7424.67, mu=712.67, sigma=6.32
#   Gaussiana 2: a=67.34, mu=751.15, sigma=43607.94
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=42377.28, mu=818.20, sigma=4.62
# 600.364 , 899.946
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=2333.05, mu=713.29, sigma=7.12
#   Gaussiana 2: a=35.72, mu=771.15, sigma=35540.68
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=38494.20, mu=818.68, sigma=4.90
# 600.364 , 899.946
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=198.76, mu=711.86, sigma=9.38
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=34057.73, mu=820.10, sigma=5.51
# 600.364 , 899.946
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=29.08, mu=709.67, sigma=11.87
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=20743.51, mu=823.25, sigma=6.81
# 600.364 , 899.946
# Nessun picco nella regione 1, skip fit.
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=12044.84, mu=831.46, sigma=8.86
# 600.364 , 899.946
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=6294.22, mu=712.38, sigma=5.67
#   Gaussiana 2: a=54.22, mu=751.90, sigma=63.72
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=16274.07, mu=818.48, sigma=4.15
# 600.364 , 899.946
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=2846.38, mu=713.62, sigma=6.04
#   Gaussiana 2: a=31.52, mu=754.16, sigma=28372.98
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=13290.19, mu=818.54, sigma=4.04
# 600.364 , 899.946
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=682.26, mu=715.38, sigma=7.10
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=13366.31, mu=819.07, sigma=4.22
# 600.364 , 899.946
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=42.77, mu=712.40, sigma=12.01
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=12869.55, mu=820.44, sigma=4.80
# 600.364 , 899.946
# Nessun picco nella regione 1, skip fit.
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=7970.84, mu=823.69, sigma=5.83
# 600.364 , 899.946
# Nessun picco nella regione 1, skip fit.
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=3947.44, mu=831.94, sigma=7.12
# 600.364 , 899.946
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=2203.78, mu=712.56, sigma=5.43
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=4164.86, mu=818.84, sigma=3.83
# 600.364 , 899.946
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=1131.87, mu=714.40, sigma=5.85
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=4658.95, mu=818.74, sigma=3.75
# 600.364 , 899.946
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=141.25, mu=717.48, sigma=7.54
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=3998.30, mu=819.23, sigma=3.91
# 600.364 , 899.946
# Nessun picco nella regione 1, skip fit.
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=3632.74, mu=820.54, sigma=4.41
# 600.364 , 899.946
# Nessun picco nella regione 1, skip fit.
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=1922.99, mu=823.83, sigma=5.13
# 600.364 , 899.946
# Nessun picco nella regione 1, skip fit.
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=734.20, mu=832.09, sigma=6.37
# 600.364 , 899.946
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=809.66, mu=712.56, sigma=5.39
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=1351.39, mu=819.25, sigma=3.81
# 600.364 , 899.946
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=361.62, mu=715.17, sigma=5.89
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=1490.68, mu=818.97, sigma=3.66
# 600.364 , 899.946
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=39.52, mu=719.06, sigma=10.44
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=1250.94, mu=819.28, sigma=3.83
# 600.364 , 899.946
# Nessun picco nella regione 1, skip fit.
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=1079.24, mu=820.53, sigma=4.25
# 600.364 , 899.946
# Nessun picco nella regione 1, skip fit.
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=549.70, mu=823.81, sigma=4.95
# 600.364 , 899.946
# Nessun picco nella regione 1, skip fit.
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=3947.44, mu=831.94, sigma=7.12
# 600.364 , 899.946
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=247.35, mu=712.57, sigma=5.56
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=360.03, mu=820.06, sigma=4.13
# 600.364 , 899.946
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=88.95, mu=716.05, sigma=6.63
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=383.13, mu=819.29, sigma=3.79
# 600.364 , 899.946
# Nessun picco nella regione 1, skip fit.
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=304.81, mu=819.34, sigma=3.97
# 600.364 , 899.946
# Nessun picco nella regione 1, skip fit.
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=212.96, mu=820.51, sigma=4.46
# 600.364 , 899.946
# Nessun picco nella regione 1, skip fit.
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=115.97, mu=823.67, sigma=5.39
# 600.364 , 899.946
# Nessun picco nella regione 1, skip fit.
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=29.18, mu=831.85, sigma=9.53
# 600.364 , 899.946
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=83.92, mu=712.61, sigma=6.16
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=106.39, mu=821.16, sigma=4.89
# 600.364 , 899.946
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=32.24, mu=716.92, sigma=9.58
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=116.87, mu=819.50, sigma=4.31
# 600.364 , 899.946
# Nessun picco nella regione 1, skip fit.
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=92.97, mu=819.37, sigma=4.68
# 600.364 , 899.946
# Nessun picco nella regione 1, skip fit.
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=67.34, mu=820.56, sigma=5.46
# 600.364 , 899.946
# Nessun picco nella regione 1, skip fit.
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=31.15, mu=823.35, sigma=8.03
# 600.364 , 899.946
# Nessun picco nella regione 1, skip fit.
# Nessun picco nella regione 2, skip fit.
# /Users/zosojack/lab-ss/QM2/varshni_subroutines.py:203: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# 600.364 , 899.946
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=2332.93, mu=711.62, sigma=6.30
#   Gaussiana 2: a=33.22, mu=749.65, sigma=79686.65
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=10912.26, mu=817.51, sigma=5.51
# 600.364 , 899.946
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=1273.38, mu=711.55, sigma=6.80
#   Gaussiana 2: a=26.32, mu=749.65, sigma=61756.45
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=9788.96, mu=817.57, sigma=5.59
# 600.364 , 899.946
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=593.93, mu=711.68, sigma=7.46
#   Gaussiana 2: a=23.44, mu=771.15, sigma=59.22
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=10068.14, mu=818.10, sigma=5.87
# 600.364 , 899.946
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=102.49, mu=710.36, sigma=9.19
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=9795.53, mu=819.48, sigma=6.61
# 600.364 , 899.946
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=25.57, mu=709.69, sigma=12.95
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=7347.90, mu=822.70, sigma=7.82
# 600.364 , 899.946
# Nessun picco nella regione 1, skip fit.
# Fit (doppia gaussiana) per Regione 2:
#   Gaussiana 1: a=3111.76, mu=828.29, sigma=12.20
#   Gaussiana 2: a=849.08, mu=835.12, sigma=5.51

# %%
raccoglitore_1
# Out:
# {'ass=0': {'emi=0o5': [{'Regione 1': [(np.float64(712.0420300258702),
#       np.float64(0.02707195546837602),
#       np.float64(5.8558259168536635)),
#      (np.float64(753.4060000000001),
#       np.float64(9466233.999606507),
#       np.float64(27611.621337107837))],
#     'Regione 2': [(np.float64(818.1285906288934),
#       np.float64(0.04151264178392018),
#       np.float64(4.634880631060973))]},
#    {'Regione 1': [(np.float64(712.6682350143399),
#       np.float64(0.02501920781341236),
#       np.float64(6.315054403463125)),
#      (np.float64(751.1490000000001),
#       np.float64(17970388.37922295),
#       np.float64(43607.93845636597))],
#     'Regione 2': [(np.float64(818.1978862493423),
#       np.float64(0.041939326987631524),
#       np.float64(4.6160474612298295))]},
#    {'Regione 1': [(np.float64(713.2948727539978),
#       np.float64(0.018272488277817807),
#       np.float64(7.118945487042437)),
#      (np.float64(771.1489999999999),
#       np.float64(8017401.220926283),
#       np.float64(35540.68220640383))],
#     'Regione 2': [(np.float64(818.6803621520963),
#       np.float64(0.04002268412241408),
#       np.float64(4.901294545931551))]},
#    {'Regione 1': [(np.float64(711.8648160448175),
#       np.float64(0.07371379026421597),
#       np.float64(9.376930220900809))],
#     'Regione 2': [(np.float64(820.1002346977282),
#       np.float64(0.048129481293030164),
#       np.float64(5.505729120768216))]},
#    {'Regione 1': [(np.float64(709.6726614399239),
#       np.float64(0.18306992801413804),
#       np.float64(11.869121263799636))],
#     'Regione 2': [(np.float64(823.2493156257457),
#       np.float64(0.08978917034628955),
#       np.float64(6.810690735138893))]},
#    {'Regione 1': [],
#     'Regione 2': [(np.float64(831.4590612366658),
#       np.float64(0.09581311133918219),
#       np.float64(8.862845558682405))]}],
#   'emi=1': [{'Regione 1': [(np.float64(712.3764006453172),
#       np.float64(0.04276700912402114),
#       np.float64(5.665893848977197)),
#      (np.float64(751.9020000000002),
#       np.float64(65.49312067680539),
#       np.float64(63.71821154141142))],
#     'Regione 2': [(np.float64(818.4772212249725),
#       np.float64(0.04466779457154027),
#       np.float64(4.154418956897287))]},
#    {'Regione 1': [(np.float64(713.6241560487672),
#       np.float64(0.03534429137024346),
#       np.float64(6.037925312547334)),
#      (np.float64(754.1580000000001),
#       np.float64(6902852.032156469),
#       np.float64(28372.979018407867))],
#     'Regione 2': [(np.float64(818.5365459554243),
#       np.float64(0.0310951031490883),
#       np.float64(4.04032148994466))]},
#    {'Regione 1': [(np.float64(715.382822740559),
#       np.float64(0.028198831609238948),
#       np.float64(7.103879068274687))],
#     'Regione 2': [(np.float64(819.0733663551417),
#       np.float64(0.031806250306047654),
#       np.float64(4.220535719495048))]},
#    {'Regione 1': [(np.float64(712.402411683322),
#       np.float64(0.13621261168697796),
#       np.float64(12.013806929657624))],
#     'Regione 2': [(np.float64(820.4449804463851),
#       np.float64(0.04747780990125493),
#       np.float64(4.802514661496983))]},
#    {'Regione 1': [],
#     'Regione 2': [(np.float64(823.686009134554),
#       np.float64(0.090685356030014),
#       np.float64(5.828032363927027))]},
#    {'Regione 1': [],
#     'Regione 2': [(np.float64(831.9397085843532),
#       np.float64(0.09570487523521123),
#       np.float64(7.11941986397349))]}],
#   'emi=1o5': [{'Regione 1': [(np.float64(712.5629326497548),
#       np.float64(0.04726169735048357),
#       np.float64(5.425171406650874))],
#     'Regione 2': [(np.float64(818.8435907851924),
#       np.float64(0.05449760992712306),
#       np.float64(3.8284425625068415))]},
#    {'Regione 1': [(np.float64(714.4031290744115),
#       np.float64(0.03113464566689235),
#       np.float64(5.8457088893320295))],
#     'Regione 2': [(np.float64(818.7358533700217),
#       np.float64(0.027152910226849042),
#       np.float64(3.749735187485357))]},
#    {'Regione 1': [(np.float64(717.476060216446),
#       np.float64(0.0435181617339117),
#       np.float64(7.539191288287727))],
#     'Regione 2': [(np.float64(819.2259460432698),
#       np.float64(0.027455181587445143),
#       np.float64(3.907654306117605))]},
#    {'Regione 1': [],
#     'Regione 2': [(np.float64(820.5438990498048),
#       np.float64(0.0477381974812106),
#       np.float64(4.413083399138684))]},
#    {'Regione 1': [],
#     'Regione 2': [(np.float64(823.8286406293372),
#       np.float64(0.08604738318049536),
#       np.float64(5.129930320457434))]},
#    {'Regione 1': [],
#     'Regione 2': [(np.float64(832.0879535750063),
#       np.float64(0.1268602916231242),
#       np.float64(6.370183304411073))]}],
#   'emi=2': [{'Regione 1': [(np.float64(712.5634792841987),
#       np.float64(0.053568047476750674),
#       np.float64(5.391516487185346))],
#     'Regione 2': [(np.float64(819.2470200253814),
#       np.float64(0.06835568883687058),
#       np.float64(3.8052669255278895))]},
#    {'Regione 1': [(np.float64(715.17138768992),
#       np.float64(0.037471870501259184),
#       np.float64(5.889940543952272))],
#     'Regione 2': [(np.float64(818.9654074850214),
#       np.float64(0.030763280029435562),
#       np.float64(3.6555562747234562))]},
#    {'Regione 1': [(np.float64(719.0561179146724),
#       np.float64(0.12950109691651002),
#       np.float64(10.441403248065688))],
#     'Regione 2': [(np.float64(819.2769837622039),
#       np.float64(0.03006544146203603),
#       np.float64(3.8343327987969325))]},
#    {'Regione 1': [],
#     'Regione 2': [(np.float64(820.532735555992),
#       np.float64(0.047425046100790645),
#       np.float64(4.247056064621295))]},
#    {'Regione 1': [],
#     'Regione 2': [(np.float64(823.8141932629658),
#       np.float64(0.0885721259555928),
#       np.float64(4.947836572001975))]},
#    {'Regione 1': [],
#     'Regione 2': [(np.float64(831.9397085843532),
#       np.float64(0.09570487523521123),
#       np.float64(7.11941986397349))]}],
#   'emi=2o5': [{'Regione 1': [(np.float64(712.5665034477204),
#       np.float64(0.05643572950170512),
#       np.float64(5.555230503748926))],
#     'Regione 2': [(np.float64(820.0593090355737),
#       np.float64(0.11557172278480113),
#       np.float64(4.12960084869228))]},
#    {'Regione 1': [(np.float64(716.0500332889019),
#       np.float64(0.06366011077237638),
#       np.float64(6.633407231793998))],
#     'Regione 2': [(np.float64(819.2920271938459),
#       np.float64(0.046231158570361836),
#       np.float64(3.7918977424285507))]},
#    {'Regione 1': [],
#     'Regione 2': [(np.float64(819.3409912398864),
#       np.float64(0.04773941720044035),
#       np.float64(3.9712899989671406))]},
#    {'Regione 1': [],
#     'Regione 2': [(np.float64(820.508477543114),
#       np.float64(0.06053409080998286),
#       np.float64(4.463960521340033))]},
#    {'Regione 1': [],
#     'Regione 2': [(np.float64(823.6714242313333),
#       np.float64(0.12763846996027234),
#       np.float64(5.385783960249659))]},
#    {'Regione 1': [],
#     'Regione 2': [(np.float64(831.8542099783797),
#       np.float64(0.1611617770286245),
#       np.float64(9.525933597621632))]}],
#   'emi=3': [{'Regione 1': [(np.float64(712.6118590055391),
#       np.float64(0.06913353541486618),
#       np.float64(6.160365306122983))],
#     'Regione 2': [(np.float64(821.16170687767),
#       np.float64(0.10877819561757046),
#       np.float64(4.885809779838457))]},
#    {'Regione 1': [(np.float64(716.9233863696005),
#       np.float64(0.14714029591148914),
#       np.float64(9.577324298028135))],
#     'Regione 2': [(np.float64(819.4995209239905),
#       np.float64(0.0885249597756304),
#       np.float64(4.312070347833196))]},
#    {'Regione 1': [],
#     'Regione 2': [(np.float64(819.3693239856373),
#       np.float64(0.09576724758291716),
#       np.float64(4.675623696818355))]},
#    {'Regione 1': [],
#     'Regione 2': [(np.float64(820.5574679514261),
#       np.float64(0.11234053279828833),
#       np.float64(5.4649552034022255))]},
#    {'Regione 1': [],
#     'Regione 2': [(np.float64(823.3517943014753),
#       np.float64(0.19512525282617102),
#       np.float64(8.031772320044603))]},
#    {'Regione 1': [], 'Regione 2': []}]},
#  'ass=1': [{'Regione 1': [(np.float64(711.615153784875),
#      np.float64(0.015205450413785076),
#      np.float64(6.3005986725738445)),
#     (np.float64(749.6450000000001),
#      np.float64(29646573.994755007),
#      np.float64(79686.65155116902))],
#    'Regione 2': [(np.float64(817.5102025605693),
#      np.float64(0.058473782791250505),
#      np.float64(5.5105862393189184))]},
#   {'Regione 1': [(np.float64(711.5527360147333),
#      np.float64(0.015342391619428889),
#      np.float64(6.795563354212011)),
#     (np.float64(749.6450000000001),
#      np.float64(11760772.74718362),
#      np.float64(61756.44876572336))],
#    'Regione 2': [(np.float64(817.5741510489815),
#      np.float64(0.05851636470269504),
#      np.float64(5.58729275386645))]},
#   {'Regione 1': [(np.float64(711.6778216250628),
#      np.float64(0.024958302103543828),
#      np.float64(7.4590374830926764)),
#     (np.float64(771.1489999999999),
#      np.float64(23.310052785521954),
#      np.float64(59.21835776222263))],
#    'Regione 2': [(np.float64(818.0960522795846),
#      np.float64(0.061414366407982826),
#      np.float64(5.867716924284707))]},
#   {'Regione 1': [(np.float64(710.3614900348803),
#      np.float64(0.07497638755701158),
#      np.float64(9.18893827991707))],
#    'Regione 2': [(np.float64(819.4767786874621),
#      np.float64(0.07195241718969334),
#      np.float64(6.612361908715961))]},
#   {'Regione 1': [(np.float64(709.6913004113204),
#      np.float64(0.16631234236448258),
#      np.float64(12.948322059575386))],
#    'Regione 2': [(np.float64(822.699875772898),
#      np.float64(0.0690966901294166),
#      np.float64(7.81519281164538))]},
#   {'Regione 1': [],
#    'Regione 2': [(np.float64(828.2904894365706),
#      np.float64(0.7852363056495706),
#      np.float64(12.197739999027602)),
#     (np.float64(835.1176851786269),
#      np.float64(0.3757418999970328),
#      np.float64(5.507521066477288))]}]}

# %% [markdown]
# ## CAMPIONE 2 CON QD

# %%
# Per ciascuno dei due valori di ass

raccoglitore_2 = {
    'ass=0': {
        'emi=0o5':  [],
        'emi=1':    [],
        'emi=1o5':  [],
        'emi=2':    [],
        'emi=2o5':  [],
        'emi=3':    []
    },
    'ass=1': []
}

for ass in d_o_ass:
    emi_list = d_o_emi[1:] if ass == '0' else ['0']  # Per ass=1 usa solo emi='0'
    
    # Per ciascuno degli emi > 0 se ass=0, solo emi=0 se ass=1
    for emi in emi_list:
        arr_energia = []

        # Ciclo sulla temperatura
        for temp in arr_temperatura:
            try:
                nome_file = build_name(campione_2, emi, ass, temp)
                asse_x, asse_y = leggi_file(nome_file)
                
            except FileNotFoundError:
                print(f"File non trovato: {nome_file}")
                continue
            
            picchi = find_peak_in_regions (asse_x, asse_y)
            
            fit_result = fit_gaussiani (asse_x, asse_y, picchi, emi, ass, temp)
            
            if ass == '1':
                raccoglitore_2['ass=1'].append(fit_result)
            else:
                raccoglitore_2['ass=0']['emi='+emi].append(fit_result)
# Out:
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=6255.63, mu=726.57, sigma=7.11
#   Gaussiana 2: a=3791.04, mu=749.05, sigma=21.87
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=45761.48, mu=818.51, sigma=4.29
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=4739.35, mu=727.59, sigma=6.75
#   Gaussiana 2: a=3997.17, mu=749.75, sigma=22.89
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=45136.06, mu=818.62, sigma=4.36
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=2515.48, mu=729.30, sigma=6.66
#   Gaussiana 2: a=304.06, mu=743.32, sigma=5.06
#   Gaussiana 3: a=3260.61, mu=757.19, sigma=22.22
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=35085.85, mu=819.18, sigma=4.37
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=2747.62, mu=762.11, sigma=19.47
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=34222.28, mu=820.85, sigma=5.09
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=971.75, mu=774.64, sigma=15.78
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=26296.11, mu=824.01, sigma=6.02
# Nessun picco nella regione 1, skip fit.
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=14559.59, mu=832.52, sigma=7.17
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=2706.46, mu=726.90, sigma=7.15
#   Gaussiana 2: a=1512.71, mu=764.55, sigma=17.93
# Fit (doppia gaussiana) per Regione 2:
#   Gaussiana 1: a=14472.34, mu=818.57, sigma=3.63
#   Gaussiana 2: a=2088.78, mu=830.86, sigma=3.83
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=1897.61, mu=728.24, sigma=6.21
#   Gaussiana 2: a=535.78, mu=733.08, sigma=16.48
#   Gaussiana 3: a=1686.41, mu=765.50, sigma=15.95
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=16013.53, mu=818.81, sigma=3.84
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=1020.61, mu=729.86, sigma=6.35
#   Gaussiana 2: a=1717.28, mu=764.36, sigma=17.82
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=13448.90, mu=819.34, sigma=3.95
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=1266.70, mu=769.24, sigma=15.26
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=10830.54, mu=821.02, sigma=4.44
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=407.45, mu=779.85, sigma=12.85
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=8348.60, mu=824.24, sigma=5.24
# Nessun picco nella regione 1, skip fit.
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=5335.60, mu=832.67, sigma=6.44
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=1201.92, mu=727.18, sigma=7.47
#   Gaussiana 2: a=561.84, mu=770.97, sigma=15.87
# Fit (doppia gaussiana) per Regione 2:
#   Gaussiana 1: a=5271.80, mu=818.70, sigma=3.41
#   Gaussiana 2: a=797.32, mu=830.71, sigma=3.99
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=774.12, mu=729.34, sigma=6.82
#   Gaussiana 2: a=603.95, mu=771.25, sigma=15.80
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=4695.63, mu=818.86, sigma=3.57
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=329.38, mu=731.94, sigma=6.84
#   Gaussiana 2: a=665.32, mu=771.53, sigma=15.15
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=4334.01, mu=819.36, sigma=3.69
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=540.15, mu=774.14, sigma=12.89
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=3854.94, mu=821.01, sigma=4.17
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=113.42, mu=783.83, sigma=12.11
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=2194.69, mu=824.22, sigma=4.81
# Nessun picco nella regione 1, skip fit.
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=1122.42, mu=832.74, sigma=5.78
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=458.99, mu=727.27, sigma=7.65
#   Gaussiana 2: a=183.29, mu=773.71, sigma=15.74
# Fit (doppia gaussiana) per Regione 2:
#   Gaussiana 1: a=1867.29, mu=818.81, sigma=3.27
#   Gaussiana 2: a=312.00, mu=830.56, sigma=4.21
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=313.01, mu=730.07, sigma=6.82
#   Gaussiana 2: a=233.43, mu=774.02, sigma=16.08
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=1821.84, mu=818.91, sigma=3.47
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=96.49, mu=733.21, sigma=7.55
#   Gaussiana 2: a=234.15, mu=774.43, sigma=15.38
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=1410.68, mu=819.34, sigma=3.62
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=137.51, mu=777.23, sigma=12.36
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=845.78, mu=820.96, sigma=4.05
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=40.28, mu=786.08, sigma=13.33
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=659.00, mu=824.19, sigma=4.69
# Nessun picco nella regione 1, skip fit.
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=220.64, mu=832.75, sigma=5.69
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=117.58, mu=727.17, sigma=7.66
#   Gaussiana 2: a=45.47, mu=774.33, sigma=21.59
# Fit (doppia gaussiana) per Regione 2:
#   Gaussiana 1: a=450.36, mu=818.89, sigma=3.21
#   Gaussiana 2: a=92.96, mu=830.63, sigma=4.98
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=79.37, mu=730.95, sigma=6.94
#   Gaussiana 2: a=67.44, mu=774.73, sigma=18.87
# Fit (doppia gaussiana) per Regione 2:
#   Gaussiana 1: a=439.71, mu=818.89, sigma=3.37
#   Gaussiana 2: a=30.06, mu=837.91, sigma=11.47
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=27.59, mu=733.10, sigma=9.33
#   Gaussiana 2: a=74.60, mu=775.50, sigma=17.14
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=358.65, mu=819.32, sigma=3.72
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=52.57, mu=777.83, sigma=13.03
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=246.13, mu=820.91, sigma=4.19
# Nessun picco nella regione 1, skip fit.
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=157.35, mu=824.12, sigma=4.95
# Nessun picco nella regione 1, skip fit.
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=40.81, mu=832.67, sigma=7.25
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=37.54, mu=726.97, sigma=7.87
#   Gaussiana 2: a=22.52, mu=784.68, sigma=47.20
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=131.38, mu=819.59, sigma=4.22
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=26.81, mu=730.38, sigma=8.15
#   Gaussiana 2: a=28.25, mu=774.19, sigma=24.20
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=120.66, mu=819.02, sigma=3.95
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=32.62, mu=775.73, sigma=17.82
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=92.46, mu=819.27, sigma=4.40
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=21.28, mu=778.62, sigma=21.56
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=59.65, mu=820.89, sigma=5.25
# Nessun picco nella regione 1, skip fit.
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=36.18, mu=824.18, sigma=6.81
# Nessun picco nella regione 1, skip fit.
# Nessun picco nella regione 2, skip fit.
# /Users/zosojack/lab-ss/QM2/varshni_subroutines.py:203: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=2358.97, mu=726.15, sigma=9.08
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=12921.60, mu=818.06, sigma=5.31
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=1919.95, mu=726.84, sigma=9.43
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=12007.57, mu=818.08, sigma=5.30
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=1072.48, mu=726.88, sigma=7.90
#   Gaussiana 2: a=736.39, mu=746.85, sigma=20.85
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=10798.63, mu=818.58, sigma=5.34
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=485.88, mu=744.70, sigma=44.08
#   Gaussiana 2: a=6.95, mu=755.62, sigma=0.78
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=8942.53, mu=820.32, sigma=6.11
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=239.78, mu=770.18, sigma=19.93
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=8687.89, mu=823.44, sigma=7.29
# Nessun picco nella regione 1, skip fit.
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=4850.67, mu=832.01, sigma=8.94

# %%
raccoglitore_2
# Out:
# {'ass=0': {'emi=0o5': [{'Regione 1': [(np.float64(726.5659055673297),
#       np.float64(0.08860662219929716),
#       np.float64(7.105351448898713)),
#      (np.float64(749.0490940856829),
#       np.float64(0.7681873649363388),
#       np.float64(21.87249085131239))],
#     'Regione 2': [(np.float64(818.5117527583785),
#       np.float64(0.056877037037743945),
#       np.float64(4.289125949347845))]},
#    {'Regione 1': [(np.float64(727.5882913131085),
#       np.float64(0.1780899369627546),
#       np.float64(6.74931581598816)),
#      (np.float64(749.7471841382809),
#       np.float64(0.9390213376678777),
#       np.float64(22.88643093922272))],
#     'Regione 2': [(np.float64(818.6187478863296),
#       np.float64(0.036401712719244264),
#       np.float64(4.3639564577385555))]},
#    {'Regione 1': [(np.float64(729.2985936846404),
#       np.float64(0.08801109333865341),
#       np.float64(6.655493860488982)),
#      (np.float64(743.321772618011),
#       np.float64(0.6399665812519937),
#       np.float64(5.055341356202531)),
#      (np.float64(757.1897892034416),
#       np.float64(0.5712271142497759),
#       np.float64(22.218368653195515))],
#     'Regione 2': [(np.float64(819.1752920649503),
#       np.float64(0.03000742515980397),
#       np.float64(4.372314722146155))]},
#    {'Regione 1': [(np.float64(762.1124264607937),
#       np.float64(0.08636711819310273),
#       np.float64(19.471662096962362))],
#     'Regione 2': [(np.float64(820.8487374677156),
#       np.float64(0.057132955469725764),
#       np.float64(5.094000952338863))]},
#    {'Regione 1': [(np.float64(774.640882986992),
#       np.float64(0.07427135044776388),
#       np.float64(15.781959680616561))],
#     'Regione 2': [(np.float64(824.0117884938774),
#       np.float64(0.0790046120982307),
#       np.float64(6.016293439385964))]},
#    {'Regione 1': [],
#     'Regione 2': [(np.float64(832.5233143585942),
#       np.float64(0.10071173473824695),
#       np.float64(7.165519997702675))]}],
#   'emi=1': [{'Regione 1': [(np.float64(726.9004519184284),
#       np.float64(0.0287777880942325),
#       np.float64(7.151706429854124)),
#      (np.float64(764.5545746608162),
#       np.float64(0.14410488998556395),
#       np.float64(17.931013060274925))],
#     'Regione 2': [(np.float64(818.571286434192),
#       np.float64(0.02028008676275435),
#       np.float64(3.6311894931077764)),
#      (np.float64(830.8626162320012),
#       np.float64(0.14345027685982878),
#       np.float64(3.8296756300840586))]},
#    {'Regione 1': [(np.float64(728.2383066288746),
#       np.float64(0.08565597294774303),
#       np.float64(6.208161635692581)),
#      (np.float64(733.0800000000002),
#       np.float64(15.454775367802213),
#       np.float64(16.48227141721598)),
#      (np.float64(765.496955538918),
#       np.float64(3.9696033169433775),
#       np.float64(15.945813395634742))],
#     'Regione 2': [(np.float64(818.8059643947803),
#       np.float64(0.030238933640945615),
#       np.float64(3.8380883205399714))]},
#    {'Regione 1': [(np.float64(729.8634363936646),
#       np.float64(0.028482359165413026),
#       np.float64(6.346080999536248)),
#      (np.float64(764.3634589650192),
#       np.float64(0.05440191250371832),
#       np.float64(17.8240899960464))],
#     'Regione 2': [(np.float64(819.3363749420687),
#       np.float64(0.02454281298410095),
#       np.float64(3.945531291307769))]},
#    {'Regione 1': [(np.float64(769.2351225629855),
#       np.float64(0.06656747968450319),
#       np.float64(15.257630835875574))],
#     'Regione 2': [(np.float64(821.0162673722122),
#       np.float64(0.05910877408955519),
#       np.float64(4.444349994034574))]},
#    {'Regione 1': [(np.float64(779.8489834377007),
#       np.float64(0.05932833874339487),
#       np.float64(12.84581278575416))],
#     'Regione 2': [(np.float64(824.2404966918605),
#       np.float64(0.089156909580601),
#       np.float64(5.23787085273593))]},
#    {'Regione 1': [],
#     'Regione 2': [(np.float64(832.6690557739236),
#       np.float64(0.10743463127506556),
#       np.float64(6.441329077217358))]}],
#   'emi=1o5': [{'Regione 1': [(np.float64(727.1765454462951),
#       np.float64(0.03698935873664156),
#       np.float64(7.471254212903522)),
#      (np.float64(770.9740473105508),
#       np.float64(0.23423430241998208),
#       np.float64(15.874209510378959))],
#     'Regione 2': [(np.float64(818.7009642978161),
#       np.float64(0.022212223588911572),
#       np.float64(3.409135707384257)),
#      (np.float64(830.7086301347823),
#       np.float64(0.15698906079175604),
#       np.float64(3.993563159721185))]},
#    {'Regione 1': [(np.float64(729.3374034151718),
#       np.float64(0.04192398733343264),
#       np.float64(6.815484773437298)),
#      (np.float64(771.2472487361632),
#       np.float64(0.17141456381524778),
#       np.float64(15.804716017096927))],
#     'Regione 2': [(np.float64(818.8611878694163),
#       np.float64(0.02572609630834094),
#       np.float64(3.566665010659977))]},
#    {'Regione 1': [(np.float64(731.941814715606),
#       np.float64(0.06455192417326135),
#       np.float64(6.8374848259831635)),
#      (np.float64(771.5257937635841),
#       np.float64(0.08466710780421592),
#       np.float64(15.154880527578175))],
#     'Regione 2': [(np.float64(819.3606557543676),
#       np.float64(0.022755874349157035),
#       np.float64(3.6932619706079355))]},
#    {'Regione 1': [(np.float64(774.1400804556715),
#       np.float64(0.05161663436596501),
#       np.float64(12.89115959365042))],
#     'Regione 2': [(np.float64(821.0094668040397),
#       np.float64(0.05790750543603526),
#       np.float64(4.167607047409608))]},
#    {'Regione 1': [(np.float64(783.8279829124782),
#       np.float64(0.06589621062598133),
#       np.float64(12.108712758493162))],
#     'Regione 2': [(np.float64(824.2243973496326),
#       np.float64(0.09341619515071217),
#       np.float64(4.813275931725878))]},
#    {'Regione 1': [],
#     'Regione 2': [(np.float64(832.7441962956686),
#       np.float64(0.12126415228688255),
#       np.float64(5.782244772539675))]}],
#   'emi=2': [{'Regione 1': [(np.float64(727.2722265449863),
#       np.float64(0.04829351146952636),
#       np.float64(7.648934368172767)),
#      (np.float64(773.7083325635517),
#       np.float64(0.2660529415806855),
#       np.float64(15.741727910360558))],
#     'Regione 2': [(np.float64(818.8057777480667),
#       np.float64(0.030375547206173407),
#       np.float64(3.268646963701075)),
#      (np.float64(830.560560693216),
#       np.float64(0.2039631776886908),
#       np.float64(4.209113598982406))]},
#    {'Regione 1': [(np.float64(730.0713733379492),
#       np.float64(0.06446693437198195),
#       np.float64(6.8236829401203645)),
#      (np.float64(774.0241420697623),
#       np.float64(0.24541483641924644),
#       np.float64(16.077848918718615))],
#     'Regione 2': [(np.float64(818.9065881081859),
#       np.float64(0.029364702401957803),
#       np.float64(3.4674866492874727))]},
#    {'Regione 1': [(np.float64(733.2144284093099),
#       np.float64(0.15279972315657367),
#       np.float64(7.548925708944436)),
#      (np.float64(774.4263126839442),
#       np.float64(0.14370176774106122),
#       np.float64(15.38431161794531))],
#     'Regione 2': [(np.float64(819.3442918024124),
#       np.float64(0.026794885823166244),
#       np.float64(3.6154249981578856))]},
#    {'Regione 1': [(np.float64(777.2329822081364),
#       np.float64(0.07317026291319038),
#       np.float64(12.355356516013435))],
#     'Regione 2': [(np.float64(820.9605887149012),
#       np.float64(0.06018171062922005),
#       np.float64(4.054077023145721))]},
#    {'Regione 1': [(np.float64(786.0751289041212),
#       np.float64(0.13340431778431186),
#       np.float64(13.327583888886707))],
#     'Regione 2': [(np.float64(824.1859831349728),
#       np.float64(0.09741256261826307),
#       np.float64(4.694563070196563))]},
#    {'Regione 1': [],
#     'Regione 2': [(np.float64(832.7522203618661),
#       np.float64(0.12570253522179056),
#       np.float64(5.689874154037762))]}],
#   'emi=2o5': [{'Regione 1': [(np.float64(727.1686451410612),
#       np.float64(0.05360257707629615),
#       np.float64(7.661624797431139)),
#      (np.float64(774.3277540201151),
#       np.float64(0.5613579509641463),
#       np.float64(21.591281040073575))],
#     'Regione 2': [(np.float64(818.8924286434594),
#       np.float64(0.040963125157549934),
#       np.float64(3.2069035542311877)),
#      (np.float64(830.6273548827338),
#       np.float64(0.2563879393995025),
#       np.float64(4.981350977615009))]},
#    {'Regione 1': [(np.float64(730.9478060737792),
#       np.float64(0.08087652481547408),
#       np.float64(6.9376069102027)),
#      (np.float64(774.7318473565903),
#       np.float64(0.33630863413188344),
#       np.float64(18.866285586757282))],
#     'Regione 2': [(np.float64(818.8863424502446),
#       np.float64(0.022694612296474216),
#       np.float64(3.3701528356861457)),
#      (np.float64(837.9095681673299),
#       np.float64(0.9023917091875152),
#       np.float64(11.465813260928162))]},
#    {'Regione 1': [(np.float64(733.0995082953214),
#       np.float64(0.23239113545920617),
#       np.float64(9.327592771933217)),
#      (np.float64(775.4993633379611),
#       np.float64(0.20822767266006378),
#       np.float64(17.13528334307466))],
#     'Regione 2': [(np.float64(819.3153222261319),
#       np.float64(0.04124849922337743),
#       np.float64(3.716837408954442))]},
#    {'Regione 1': [(np.float64(777.8287692617411),
#       np.float64(0.09722816875645936),
#       np.float64(13.029194169704372))],
#     'Regione 2': [(np.float64(820.9122871746252),
#       np.float64(0.07656026009169734),
#       np.float64(4.1920892614449))]},
#    {'Regione 1': [],
#     'Regione 2': [(np.float64(824.1182539434927),
#       np.float64(0.11102137146249696),
#       np.float64(4.94535760733613))]},
#    {'Regione 1': [],
#     'Regione 2': [(np.float64(832.6730600391595),
#       np.float64(0.14898771983815068),
#       np.float64(7.2542223622860185))]}],
#   'emi=3': [{'Regione 1': [(np.float64(726.9662343800998),
#       np.float64(0.13001053870466542),
#       np.float64(7.872229823676368)),
#      (np.float64(784.6799999995733),
#       np.float64(6.624270474740195),
#       np.float64(47.196813648601584))],
#     'Regione 2': [(np.float64(819.5870272202823),
#       np.float64(0.18221428710854662),
#       np.float64(4.2176205446902575))]},
#    {'Regione 1': [(np.float64(730.3806423390488),
#       np.float64(0.14398115599795036),
#       np.float64(8.149268508344736)),
#      (np.float64(774.1946879632457),
#       np.float64(0.5526632960743053),
#       np.float64(24.202154384314348))],
#     'Regione 2': [(np.float64(819.0228576302316),
#       np.float64(0.0939748349373567),
#       np.float64(3.951805364918671))]},
#    {'Regione 1': [(np.float64(775.7333001735113),
#       np.float64(0.2539118047590583),
#       np.float64(17.821901324163896))],
#     'Regione 2': [(np.float64(819.2688193744123),
#       np.float64(0.09962181252864197),
#       np.float64(4.4001663611498465))]},
#    {'Regione 1': [(np.float64(778.6187958754025),
#       np.float64(0.5304952677391686),
#       np.float64(21.558095704082245))],
#     'Regione 2': [(np.float64(820.8910012491275),
#       np.float64(0.1338239116856578),
#       np.float64(5.249137828118373))]},
#    {'Regione 1': [],
#     'Regione 2': [(np.float64(824.184666378226),
#       np.float64(0.17528519929063363),
#       np.float64(6.813021768301722))]},
#    {'Regione 1': [], 'Regione 2': []}]},
#  'ass=1': [{'Regione 1': [(np.float64(726.1531073174856),
#      np.float64(0.052749886647087504),
#      np.float64(9.076868224584032))],
#    'Regione 2': [(np.float64(818.0561647586861),
#      np.float64(0.08259338970359506),
#      np.float64(5.308342382992744))]},
#   {'Regione 1': [(np.float64(726.8449815846959),
#      np.float64(0.07607391997501303),
#      np.float64(9.433708260303447))],
#    'Regione 2': [(np.float64(818.0802963366182),
#      np.float64(0.057871526156751424),
#      np.float64(5.304995448904124))]},
#   {'Regione 1': [(np.float64(726.881416257503),
#      np.float64(0.2385783988798824),
#      np.float64(7.904315924887948)),
#     (np.float64(746.8540842418153),
#      np.float64(2.681998186075525),
#      np.float64(20.846368070990913))],
#    'Regione 2': [(np.float64(818.5762015522672),
#      np.float64(0.05295300710303534),
#      np.float64(5.344891030422629))]},
#   {'Regione 1': [(np.float64(744.7035955918797),
#      np.float64(0.4718354749937292),
#      np.float64(44.07984804138746)),
#     (np.float64(755.6160008334207),
#      np.float64(0.4442406475114662),
#      np.float64(0.7817283957626489))],
#    'Regione 2': [(np.float64(820.3246734615042),
#      np.float64(0.06142514857825656),
#      np.float64(6.105480361570837))]},
#   {'Regione 1': [(np.float64(770.1777308309486),
#      np.float64(0.09948445390744351),
#      np.float64(19.934458738383835))],
#    'Regione 2': [(np.float64(823.4438725034407),
#      np.float64(0.08360329353121265),
#      np.float64(7.2934267750361474))]},
#   {'Regione 1': [],
#    'Regione 2': [(np.float64(832.0095604865489),
#      np.float64(0.09189853907299671),
#      np.float64(8.941372878807757))]}]}
