# %% [markdown]
# # Picchi al variare dell'intensità in tre diversi spot

# %%
from varshni_subroutines import *

import warnings
warnings.filterwarnings("ignore", category=pd.errors.ParserWarning)

# %% [markdown]
# ## Parte 0: nomi file e funzioni

# %%
# Nomi file 
# orangeF sta per filtro arancione
campione_1 = 'C240830_'
campione_2 = 'C240920_'
d_o_emi = ['0', '0o5', '1', '1o5', '2', '2o5', '3']#, '3o5']
d_o_ass = ['0', '1']
arr_spot = [1, 2, 3]

# %% [markdown]
# ## CAMPIONE 1 REFERENCE

# %%
raccoglitore_1 = {
    'spot1': {
        'ass=0': {
            'emi=0o5':  [],
            'emi=1':    [],
            'emi=1o5':  [],
            'emi=2':    [],
            'emi=2o5':  [],
            'emi=3':    []
        },
        'ass=1': []
    },
    'spot2': {
        'ass=0': {
            'emi=0o5':  [],
            'emi=1':    [],
            'emi=1o5':  [],
            'emi=2':    [],
            'emi=2o5':  [],
            'emi=3':    []
        },
        'ass=1': []
    },
    'spot3': {
        'ass=0': {
            'emi=0o5':  [],
            'emi=1':    [],
            'emi=1o5':  [],
            'emi=2':    [],
            'emi=2o5':  [],
            'emi=3':    []
        },
        'ass=1': []
    }
}

# %%
for ass in d_o_ass:
    emi_list = d_o_emi[1:] if ass == '0' else ['0']  # Per ass=1 usa solo emi='0'
    
    # Per ciascuno degli emi > 0 se ass=0, solo emi=0 se ass=1
    for emi in emi_list:
        arr_energia = []

        # Ciclo sugli spot
        for spot in arr_spot:
            try:
                nome_file = spot_name(campione_1, emi, ass, spot)
                asse_x, asse_y = leggi_file(nome_file)
                print(min(asse_x), ',', max(asse_x))
            except FileNotFoundError:
                print(f"File non trovato: {nome_file}")
                continue
            
            picchi = find_peak_in_regions (asse_x, asse_y)
            
            fit_result = fit_gaussiani (asse_x, asse_y, picchi, emi, ass, spot, 5)
            
            if ass == '1':
                raccoglitore_1['spot'+str(spot)]['ass=1'].append(fit_result)
            else:
                raccoglitore_1['spot'+str(spot)]['ass=0']['emi='+emi].append(fit_result)
# Out:
# 600.36 , 899.95
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=14913.09, mu=712.04, sigma=5.70
#   Gaussiana 2: a=101.82, mu=752.65, sigma=19972.93
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=48122.50, mu=818.16, sigma=4.48
# 600.364 , 899.946
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=13001.93, mu=712.03, sigma=5.72
#   Gaussiana 2: a=94.87, mu=751.90, sigma=243.18
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=39346.81, mu=818.17, sigma=4.50
# 600.364 , 899.946
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=6332.08, mu=712.33, sigma=5.54
#   Gaussiana 2: a=50.46, mu=754.16, sigma=72.36
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=14956.33, mu=818.44, sigma=4.05
# 600.36 , 899.95
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=6585.58, mu=712.30, sigma=5.52
#   Gaussiana 2: a=48.98, mu=753.41, sigma=73.05
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=16151.43, mu=818.46, sigma=4.04
# 600.364 , 899.946
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=5643.06, mu=712.40, sigma=5.50
#   Gaussiana 2: a=44.67, mu=756.41, sigma=85.88
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=13110.10, mu=818.59, sigma=4.07
# 600.364 , 899.946
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=6462.06, mu=712.32, sigma=5.57
#   Gaussiana 2: a=51.98, mu=754.16, sigma=74.02
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=15762.41, mu=818.41, sigma=4.08
# 600.36 , 899.95
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=2512.88, mu=712.40, sigma=5.30
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=4817.25, mu=818.88, sigma=3.84
# 600.364 , 899.946
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=1818.59, mu=712.42, sigma=5.31
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=3350.81, mu=818.98, sigma=3.87
# 600.364 , 899.946
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=2315.02, mu=712.43, sigma=5.39
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=4558.57, mu=818.71, sigma=3.86
# 600.36 , 899.95
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=821.65, mu=712.38, sigma=5.25
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=1373.54, mu=819.45, sigma=3.90
# 600.364 , 899.946
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=868.91, mu=712.34, sigma=5.28
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=1362.61, mu=819.46, sigma=3.87
# 600.364 , 899.946
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=744.34, mu=712.45, sigma=5.32
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=1221.22, mu=819.24, sigma=3.85
# 600.36 , 899.95
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=224.62, mu=712.42, sigma=5.42
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=337.33, mu=820.38, sigma=4.22
# 600.364 , 899.946
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=293.91, mu=712.39, sigma=5.40
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=420.02, mu=820.41, sigma=4.20
# 600.364 , 899.946
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=185.71, mu=712.49, sigma=5.56
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=267.43, mu=820.23, sigma=4.28
# 600.36 , 899.95
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=80.64, mu=712.52, sigma=6.01
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=107.52, mu=821.57, sigma=5.13
# 600.364 , 899.946
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=89.99, mu=712.61, sigma=6.05
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=112.90, mu=821.60, sigma=5.00
# 600.364 , 899.946
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=75.51, mu=712.54, sigma=6.18
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=101.16, mu=821.10, sigma=4.96
# 600.36 , 899.95
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=3116.81, mu=711.64, sigma=6.09
#   Gaussiana 2: a=35.27, mu=751.15, sigma=153012.44
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=14723.62, mu=817.61, sigma=5.21
# 600.364 , 899.946
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=3509.89, mu=711.69, sigma=6.04
#   Gaussiana 2: a=39.17, mu=751.15, sigma=46966.09
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=14439.60, mu=817.71, sigma=5.10
# 600.364 , 899.946
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=2979.63, mu=711.54, sigma=6.14
#   Gaussiana 2: a=36.47, mu=751.15, sigma=51139.10
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=13264.69, mu=817.51, sigma=5.23

# %% [markdown]
# ## CAMPIONE 2 QD

# %%
raccoglitore_2 = {
    'spot1': {
        'ass=0': {
            'emi=0o5':  [],
            'emi=1':    [],
            'emi=1o5':  [],
            'emi=2':    [],
            'emi=2o5':  [],
            'emi=3':    []
        },
        'ass=1': []
    },
    'spot2': {
        'ass=0': {
            'emi=0o5':  [],
            'emi=1':    [],
            'emi=1o5':  [],
            'emi=2':    [],
            'emi=2o5':  [],
            'emi=3':    []
        },
        'ass=1': []
    },
    'spot3': {
        'ass=0': {
            'emi=0o5':  [],
            'emi=1':    [],
            'emi=1o5':  [],
            'emi=2':    [],
            'emi=2o5':  [],
            'emi=3':    []
        },
        'ass=1': []
    }
}

# %%
for ass in d_o_ass:
    emi_list = d_o_emi[1:] if ass == '0' else ['0']  # Per ass=1 usa solo emi='0'
    
    # Per ciascuno degli emi > 0 se ass=0, solo emi=0 se ass=1
    for emi in emi_list:
        arr_energia = []

        # Ciclo sugli spot
        for spot in arr_spot:
            try:
                nome_file = spot_name(campione_2, emi, ass, spot)
                asse_x, asse_y = leggi_file(nome_file)
                print(min(asse_x), ',', max(asse_x))
            except FileNotFoundError:
                print(f"File non trovato: {nome_file}")
                continue
            
            picchi = find_peak_in_regions (asse_x, asse_y, 20, 4, 3)
            
            fit_result = fit_gaussiani (asse_x, asse_y, picchi, emi, ass, spot, 5)
            
            if ass == '1':
                raccoglitore_2['spot'+str(spot)]['ass=1'].append(fit_result)
            else:
                raccoglitore_2['spot'+str(spot)]['ass=0']['emi='+emi].append(fit_result)
# Out:
# 600.364 , 899.946
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=4383.18, mu=726.93, sigma=6.93
#   Gaussiana 2: a=2733.61, mu=747.92, sigma=24.08
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=35241.02, mu=818.77, sigma=4.36
# 600.364 , 899.946
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=3612.43, mu=727.03, sigma=7.19
#   Gaussiana 2: a=1731.89, mu=766.97, sigma=16.78
# Fit (doppia gaussiana) per Regione 2:
#   Gaussiana 1: a=16561.51, mu=818.64, sigma=3.53
#   Gaussiana 2: a=2372.44, mu=830.73, sigma=4.05
# 600.364 , 899.946
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=10112.18, mu=726.46, sigma=7.26
#   Gaussiana 2: a=4624.28, mu=763.90, sigma=18.77
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=48914.97, mu=818.57, sigma=3.94
# 600.364 , 899.946
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=2004.10, mu=726.98, sigma=6.73
#   Gaussiana 2: a=1281.81, mu=759.54, sigma=23.23
# Fit (doppia gaussiana) per Regione 2:
#   Gaussiana 1: a=13322.70, mu=818.77, sigma=3.71
#   Gaussiana 2: a=2164.94, mu=831.21, sigma=3.84
# 600.364 , 899.946
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=3077.34, mu=726.95, sigma=7.20
#   Gaussiana 2: a=1583.40, mu=766.73, sigma=16.70
# Fit (doppia gaussiana) per Regione 2:
#   Gaussiana 1: a=14596.94, mu=818.59, sigma=3.56
#   Gaussiana 2: a=1954.36, mu=830.74, sigma=3.91
# 600.364 , 899.946
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=4909.24, mu=726.96, sigma=7.46
#   Gaussiana 2: a=2072.97, mu=770.08, sigma=15.51
# Fit (doppia gaussiana) per Regione 2:
#   Gaussiana 1: a=20588.79, mu=818.61, sigma=3.49
#   Gaussiana 2: a=2267.98, mu=830.42, sigma=4.11
# 600.364 , 899.946
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=828.06, mu=727.57, sigma=7.23
#   Gaussiana 2: a=428.83, mu=769.58, sigma=15.82
# Fit (doppia gaussiana) per Regione 2:
#   Gaussiana 1: a=3919.26, mu=818.89, sigma=3.36
#   Gaussiana 2: a=633.68, mu=830.79, sigma=4.29
# 600.364 , 899.946
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=1272.30, mu=727.14, sigma=7.54
#   Gaussiana 2: a=577.69, mu=771.66, sigma=15.08
# Fit (doppia gaussiana) per Regione 2:
#   Gaussiana 1: a=5294.65, mu=818.67, sigma=3.38
#   Gaussiana 2: a=741.10, mu=830.65, sigma=4.06
# 600.364 , 899.946
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=1566.45, mu=727.14, sigma=7.61
#   Gaussiana 2: a=575.70, mu=774.29, sigma=15.33
# Fit (doppia gaussiana) per Regione 2:
#   Gaussiana 1: a=6176.87, mu=818.65, sigma=3.26
#   Gaussiana 2: a=716.37, mu=829.82, sigma=4.69
# 600.364 , 899.946
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=299.07, mu=727.68, sigma=7.48
#   Gaussiana 2: a=135.66, mu=773.54, sigma=16.85
# Fit (doppia gaussiana) per Regione 2:
#   Gaussiana 1: a=1264.88, mu=818.93, sigma=3.21
#   Gaussiana 2: a=222.07, mu=830.56, sigma=4.79
# 600.364 , 899.946
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=362.72, mu=727.23, sigma=7.65
#   Gaussiana 2: a=133.37, mu=774.58, sigma=16.75
# Fit (doppia gaussiana) per Regione 2:
#   Gaussiana 1: a=1401.44, mu=818.80, sigma=3.20
#   Gaussiana 2: a=226.62, mu=830.37, sigma=4.75
# 600.364 , 899.946
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=431.16, mu=727.15, sigma=7.63
#   Gaussiana 2: a=132.72, mu=776.21, sigma=18.18
# Fit (doppia gaussiana) per Regione 2:
#   Gaussiana 1: a=1655.63, mu=818.76, sigma=3.11
#   Gaussiana 2: a=223.05, mu=829.29, sigma=5.48
# 600.364 , 899.946
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=104.75, mu=727.52, sigma=7.73
#   Gaussiana 2: a=45.61, mu=775.25, sigma=21.52
# Fit (doppia gaussiana) per Regione 2:
#   Gaussiana 1: a=394.86, mu=819.01, sigma=3.16
#   Gaussiana 2: a=84.32, mu=830.61, sigma=5.38
# 600.364 , 899.946
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=119.11, mu=727.15, sigma=7.71
#   Gaussiana 2: a=44.34, mu=774.26, sigma=21.70
# Fit (doppia gaussiana) per Regione 2:
#   Gaussiana 1: a=424.87, mu=818.87, sigma=3.19
#   Gaussiana 2: a=84.02, mu=830.48, sigma=5.61
# 600.364 , 899.946
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=118.30, mu=727.09, sigma=7.70
#   Gaussiana 2: a=38.35, mu=774.02, sigma=24.00
# Fit (doppia gaussiana) per Regione 2:
#   Gaussiana 1: a=402.28, mu=818.90, sigma=3.14
#   Gaussiana 2: a=72.13, mu=829.54, sigma=6.65
# 600.364 , 899.946
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=43.20, mu=727.40, sigma=9.81
# Fit (doppia gaussiana) per Regione 2:
#   Gaussiana 1: a=88.22, mu=819.00, sigma=2.88
#   Gaussiana 2: a=36.82, mu=827.15, sigma=11.22
# 600.364 , 899.946
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=41.26, mu=726.63, sigma=7.93
#   Gaussiana 2: a=22.56, mu=772.69, sigma=30.89
# Fit (doppia gaussiana) per Regione 2:
#   Gaussiana 1: a=103.90, mu=818.89, sigma=2.97
#   Gaussiana 2: a=36.42, mu=827.23, sigma=11.18
# 600.364 , 899.946
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=49.80, mu=727.53, sigma=9.50
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=121.81, mu=819.60, sigma=4.24
# 600.364 , 899.946
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=2022.60, mu=726.23, sigma=9.36
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=12177.32, mu=818.29, sigma=5.31
# 600.364 , 899.946
# Fit (singola gaussiana) per Regione 1:
#   Gaussiana 1: a=2530.46, mu=727.07, sigma=8.94
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=13041.77, mu=818.20, sigma=4.84
# 600.364 , 899.946
# Fit (doppia gaussiana) per Regione 1:
#   Gaussiana 1: a=2726.70, mu=726.33, sigma=6.88
#   Gaussiana 2: a=1483.18, mu=748.89, sigma=26.81
# Fit (singola gaussiana) per Regione 2:
#   Gaussiana 1: a=19127.31, mu=818.34, sigma=4.44

# %%
raccoglitore_1
# Out:
# {'spot1': {'ass=0': {'emi=0o5': [{'Regione 1': [(np.float64(712.0425412738123),
#        np.float64(0.03682058367839299),
#        np.float64(5.6968113641576785)),
#       (np.float64(752.6500000000001),
#        np.float64(5994696.9658144),
#        np.float64(19972.927486191966))],
#      'Regione 2': [(np.float64(818.1639827760961),
#        np.float64(0.04455474959411525),
#        np.float64(4.483082947141471))]}],
#    'emi=1': [{'Regione 1': [(np.float64(712.2985999928571),
#        np.float64(0.03922017791671765),
#        np.float64(5.519350619558212)),
#       (np.float64(753.4100000000001),
#        np.float64(92.87725174781431),
#        np.float64(73.05028308616039))],
#      'Regione 2': [(np.float64(818.4646378237444),
#        np.float64(0.051997659995058176),
#        np.float64(4.036525076879772))]}],
#    'emi=1o5': [{'Regione 1': [(np.float64(712.4000701984996),
#        np.float64(0.043544554728635367),
#        np.float64(5.29571134828238))],
#      'Regione 2': [(np.float64(818.8767056355529),
#        np.float64(0.06446365573164524),
#        np.float64(3.8408892741925063))]}],
#    'emi=2': [{'Regione 1': [(np.float64(712.3788338094838),
#        np.float64(0.04904756896977745),
#        np.float64(5.250095074984835))],
#      'Regione 2': [(np.float64(819.454288061073),
#        np.float64(0.09569405901208299),
#        np.float64(3.8979739936680895))]}],
#    'emi=2o5': [{'Regione 1': [(np.float64(712.4150119455958),
#        np.float64(0.05612458021419752),
#        np.float64(5.4234839944419075))],
#      'Regione 2': [(np.float64(820.3805092981333),
#        np.float64(0.12423427133213653),
#        np.float64(4.22330125290069))]}],
#    'emi=3': [{'Regione 1': [(np.float64(712.522881885126),
#        np.float64(0.059236981854447354),
#        np.float64(6.009242319589382))],
#      'Regione 2': [(np.float64(821.5684102140544),
#        np.float64(0.13943955385695764),
#        np.float64(5.132830869939324))]}]},
#   'ass=1': [{'Regione 1': [(np.float64(711.6441248590014),
#       np.float64(0.01676215399031646),
#       np.float64(6.0922469344150825)),
#      (np.float64(751.1500000000001),
#       np.float64(128493837.99747348),
#       np.float64(153012.4439034226))],
#     'Regione 2': [(np.float64(817.6110137564798),
#       np.float64(0.05299581794296689),
#       np.float64(5.213549562830013))]}]},
#  'spot2': {'ass=0': {'emi=0o5': [{'Regione 1': [(np.float64(712.0252710296875),
#        np.float64(0.042333009007792674),
#        np.float64(5.718787607212309)),
#       (np.float64(751.9020000000002),
#        np.float64(919.5202011385452),
#        np.float64(243.18272635805712))],
#      'Regione 2': [(np.float64(818.1683395299981),
#        np.float64(0.040331323073641526),
#        np.float64(4.500530641167661))]}],
#    'emi=1': [{'Regione 1': [(np.float64(712.3971504344609),
#        np.float64(0.043562539661050385),
#        np.float64(5.4980024209780405)),
#       (np.float64(756.4140000000001),
#        np.float64(134.69392546788862),
#        np.float64(85.87791765299025))],
#      'Regione 2': [(np.float64(818.590808718429),
#        np.float64(0.048940278906881414),
#        np.float64(4.072083337734387))]}],
#    'emi=1o5': [{'Regione 1': [(np.float64(712.4166720251698),
#        np.float64(0.05304990467160133),
#        np.float64(5.311629397755867))],
#      'Regione 2': [(np.float64(818.9815788904812),
#        np.float64(0.07911103169871771),
#        np.float64(3.86669363638469))]}],
#    'emi=2': [{'Regione 1': [(np.float64(712.3443393396129),
#        np.float64(0.05782356789170549),
#        np.float64(5.2813314801466245))],
#      'Regione 2': [(np.float64(819.4582725662284),
#        np.float64(0.08953491735764456),
#        np.float64(3.865737306296007))]}],
#    'emi=2o5': [{'Regione 1': [(np.float64(712.3867870187803),
#        np.float64(0.060892905517945004),
#        np.float64(5.3996355155436095))],
#      'Regione 2': [(np.float64(820.4067851875782),
#        np.float64(0.1345679075888006),
#        np.float64(4.204290391945278))]}],
#    'emi=3': [{'Regione 1': [(np.float64(712.6053786258153),
#        np.float64(0.07668405880978342),
#        np.float64(6.052573830622703))],
#      'Regione 2': [(np.float64(821.6006735289926),
#        np.float64(0.12595656243276857),
#        np.float64(5.002447595172151))]}]},
#   'ass=1': [{'Regione 1': [(np.float64(711.6883014742027),
#       np.float64(0.024837474978428923),
#       np.float64(6.042666242131656)),
#      (np.float64(751.1490000000001),
#       np.float64(16093335.205471538),
#       np.float64(46966.09479228215))],
#     'Regione 2': [(np.float64(817.7061298869954),
#       np.float64(0.04424092694324465),
#       np.float64(5.103113630256257))]}]},
#  'spot3': {'ass=0': {'emi=0o5': [{'Regione 1': [(np.float64(712.3269140701901),
#        np.float64(0.044749553506366786),
#        np.float64(5.544637420779298)),
#       (np.float64(754.1580000000002),
#        np.float64(97.50400198981167),
#        np.float64(72.35782209438509))],
#      'Regione 2': [(np.float64(818.4378016857072),
#        np.float64(0.048310118626605766),
#        np.float64(4.045713830975041))]}],
#    'emi=1': [{'Regione 1': [(np.float64(712.3215513696381),
#        np.float64(0.0453775246059109),
#        np.float64(5.56949913140506)),
#       (np.float64(754.1580000000001),
#        np.float64(101.10271557096559),
#        np.float64(74.02474689937303))],
#      'Regione 2': [(np.float64(818.4051515952051),
#        np.float64(0.048832216691300195),
#        np.float64(4.079743840227578))]}],
#    'emi=1o5': [{'Regione 1': [(np.float64(712.4314892917021),
#        np.float64(0.05294332415444096),
#        np.float64(5.386008579655006))],
#      'Regione 2': [(np.float64(818.7075879739996),
#        np.float64(0.07036529089339671),
#        np.float64(3.8598274603770646))]}],
#    'emi=2': [{'Regione 1': [(np.float64(712.445842870958),
#        np.float64(0.059611057715176934),
#        np.float64(5.320880739898997))],
#      'Regione 2': [(np.float64(819.2383880875107),
#        np.float64(0.0906594419999166),
#        np.float64(3.85093460238782))]}],
#    'emi=2o5': [{'Regione 1': [(np.float64(712.486374365651),
#        np.float64(0.06423652981538626),
#        np.float64(5.555188003841079))],
#      'Regione 2': [(np.float64(820.2275857744426),
#        np.float64(0.13440630220053418),
#        np.float64(4.2845444876853005))]}],
#    'emi=3': [{'Regione 1': [(np.float64(712.5361866974339),
#        np.float64(0.0827394507824735),
#        np.float64(6.180109016430614))],
#      'Regione 2': [(np.float64(821.1035070485448),
#        np.float64(0.13058214887142355),
#        np.float64(4.955750139611843))]}]},
#   'ass=1': [{'Regione 1': [(np.float64(711.5412231679661),
#       np.float64(0.02003760297200771),
#       np.float64(6.141189241792213)),
#      (np.float64(751.1490000000001),
#       np.float64(14724818.459063975),
#       np.float64(51139.10382260142))],
#     'Regione 2': [(np.float64(817.5133336747725),
#       np.float64(0.053865213854087844),
#       np.float64(5.228963437373166))]}]}}

# %%
raccoglitore_2
# Out:
# {'spot1': {'ass=0': {'emi=0o5': [{'Regione 1': [(np.float64(726.9337520641654),
#        np.float64(0.10314532968342252),
#        np.float64(6.928294439480226)),
#       (np.float64(747.9221278519261),
#        np.float64(1.09416991964861),
#        np.float64(24.078489299690972))],
#      'Regione 2': [(np.float64(818.7653328887187),
#        np.float64(0.08024740698487139),
#        np.float64(4.355303017592534))]}],
#    'emi=1': [{'Regione 1': [(np.float64(726.9823694174521),
#        np.float64(0.02254716454644121),
#        np.float64(6.725373605207883)),
#       (np.float64(759.5386355552012),
#        np.float64(0.1690544000804027),
#        np.float64(23.233516117195975))],
#      'Regione 2': [(np.float64(818.7710964715595),
#        np.float64(0.02817406306585801),
#        np.float64(3.7066939845956917)),
#       (np.float64(831.2070067926768),
#        np.float64(0.1757386653441904),
#        np.float64(3.8363933505350034))]}],
#    'emi=1o5': [{'Regione 1': [(np.float64(727.5692023860072),
#        np.float64(0.031652015171005146),
#        np.float64(7.230776894609416)),
#       (np.float64(769.581836660975),
#        np.float64(0.1569410777573073),
#        np.float64(15.816199739826098))],
#      'Regione 2': [(np.float64(818.8867373147029),
#        np.float64(0.02472467085415246),
#        np.float64(3.3573221170520204)),
#       (np.float64(830.7861244620902),
#        np.float64(0.17156090782140604),
#        np.float64(4.292565716971287))]}],
#    'emi=2': [{'Regione 1': [(np.float64(727.681729637501),
#        np.float64(0.04629746825015596),
#        np.float64(7.477599884092002)),
#       (np.float64(773.5353682819193),
#        np.float64(0.29174723218414284),
#        np.float64(16.851705586567586))],
#      'Regione 2': [(np.float64(818.9322662028254),
#        np.float64(0.030829458314194483),
#        np.float64(3.2112469907042245)),
#       (np.float64(830.5610676365453),
#        np.float64(0.22234328610887563),
#        np.float64(4.792649063596919))]}],
#    'emi=2o5': [{'Regione 1': [(np.float64(727.5201992742657),
#        np.float64(0.056027804056600884),
#        np.float64(7.725553197210685)),
#       (np.float64(775.2495317242842),
#        np.float64(0.5702536043055371),
#        np.float64(21.520533107835668))],
#      'Regione 2': [(np.float64(819.0058025334542),
#        np.float64(0.04099858444376061),
#        np.float64(3.1584112409975065)),
#       (np.float64(830.6071743910275),
#        np.float64(0.2821391448344837),
#        np.float64(5.382848630652848))]}],
#    'emi=3': [{'Regione 1': [(np.float64(727.4017491815104),
#        np.float64(0.12368758377198359),
#        np.float64(9.8079639896573))],
#      'Regione 2': [(np.float64(818.9956332363133),
#        np.float64(0.055890330890149845),
#        np.float64(2.87758178682265)),
#       (np.float64(827.1487556703781),
#        np.float64(0.48244412151628085),
#        np.float64(11.217304412304607))]}]},
#   'ass=1': [{'Regione 1': [(np.float64(726.2304699411663),
#       np.float64(0.06663139747103067),
#       np.float64(9.360522323437676))],
#     'Regione 2': [(np.float64(818.2857090404738),
#       np.float64(0.08754428559242276),
#       np.float64(5.306132663039096))]}]},
#  'spot2': {'ass=0': {'emi=0o5': [{'Regione 1': [(np.float64(727.0276214442038),
#        np.float64(0.029355608521535365),
#        np.float64(7.187651691542487)),
#       (np.float64(766.9709102637105),
#        np.float64(0.1895530359870442),
#        np.float64(16.778221610847634))],
#      'Regione 2': [(np.float64(818.6394600807128),
#        np.float64(0.024345284627945444),
#        np.float64(3.5258527101991852)),
#       (np.float64(830.7252554253525),
#        np.float64(0.18009716328350572),
#        np.float64(4.052273258972058))]}],
#    'emi=1': [{'Regione 1': [(np.float64(726.9535555747561),
#        np.float64(0.029219082819362394),
#        np.float64(7.204769198344571)),
#       (np.float64(766.7296909199064),
#        np.float64(0.16890785441000394),
#        np.float64(16.70144223255332))],
#      'Regione 2': [(np.float64(818.5905350410609),
#        np.float64(0.023625869895329003),
#        np.float64(3.5591328019100126)),
#       (np.float64(830.7409559329998),
#        np.float64(0.18333701662065816),
#        np.float64(3.9136925247354064))]}],
#    'emi=1o5': [{'Regione 1': [(np.float64(727.1364597370825),
#        np.float64(0.04027478512084775),
#        np.float64(7.535248299961953)),
#       (np.float64(771.6603883348065),
#        np.float64(0.20804119736014795),
#        np.float64(15.082830165044786))],
#      'Regione 2': [(np.float64(818.6714034415678),
#        np.float64(0.029287692627451175),
#        np.float64(3.383540941426331)),
#       (np.float64(830.6458931719175),
#        np.float64(0.22610062689490584),
#        np.float64(4.057561822120804))]}],
#    'emi=2': [{'Regione 1': [(np.float64(727.2311957816446),
#        np.float64(0.05285275201805235),
#        np.float64(7.651657380669469)),
#       (np.float64(774.5817312646526),
#        np.float64(0.38853766359937814),
#        np.float64(16.745517943789835))],
#      'Regione 2': [(np.float64(818.7976043616904),
#        np.float64(0.044206266450787714),
#        np.float64(3.2009460134629553)),
#       (np.float64(830.3705636412993),
#        np.float64(0.3431500750857772),
#        np.float64(4.746867998774641))]}],
#    'emi=2o5': [{'Regione 1': [(np.float64(727.1471354987675),
#        np.float64(0.05633506235361278),
#        np.float64(7.70943660656019)),
#       (np.float64(774.2553963754519),
#        np.float64(0.5667125164640433),
#        np.float64(21.697432965318917))],
#      'Regione 2': [(np.float64(818.8678096907503),
#        np.float64(0.05535848205271789),
#        np.float64(3.190070836516803)),
#       (np.float64(830.4843402608667),
#        np.float64(0.43846457623767576),
#        np.float64(5.609131029551118))]}],
#    'emi=3': [{'Regione 1': [(np.float64(726.6314824799805),
#        np.float64(0.08931336841045996),
#        np.float64(7.933376984052271)),
#       (np.float64(772.6926294091516),
#        np.float64(0.9162163826353831),
#        np.float64(30.894169205805603))],
#      'Regione 2': [(np.float64(818.8885495831368),
#        np.float64(0.055966433865786695),
#        np.float64(2.971637247071907)),
#       (np.float64(827.2297015260062),
#        np.float64(0.594768388322004),
#        np.float64(11.177208301796854))]}]},
#   'ass=1': [{'Regione 1': [(np.float64(727.0694867722107),
#       np.float64(0.07032629579558106),
#       np.float64(8.935696017087048))],
#     'Regione 2': [(np.float64(818.2009345690484),
#       np.float64(0.06591719308092672),
#       np.float64(4.841768772724061))]}]},
#  'spot3': {'ass=0': {'emi=0o5': [{'Regione 1': [(np.float64(726.4633371882502),
#        np.float64(0.024655794344063335),
#        np.float64(7.261688609435478)),
#       (np.float64(763.8987656196214),
#        np.float64(0.1699172857004163),
#        np.float64(18.77362358826881))],
#      'Regione 2': [(np.float64(818.5684894920172),
#        np.float64(0.04456597490827444),
#        np.float64(3.936286993053745))]}],
#    'emi=1': [{'Regione 1': [(np.float64(726.9559638527943),
#        np.float64(0.03365366024080526),
#        np.float64(7.45984564725815)),
#       (np.float64(770.0762706808465),
#        np.float64(0.21518600924368342),
#        np.float64(15.511998597657207))],
#      'Regione 2': [(np.float64(818.6060958470615),
#        np.float64(0.02134623690506526),
#        np.float64(3.4889917217451636)),
#       (np.float64(830.4217094861505),
#        np.float64(0.20750198989248317),
#        np.float64(4.109052495094495))]}],
#    'emi=1o5': [{'Regione 1': [(np.float64(727.141817697883),
#        np.float64(0.045827811395617535),
#        np.float64(7.612785060932302)),
#       (np.float64(774.2928628300799),
#        np.float64(0.32185386922575826),
#        np.float64(15.334288946416255))],
#      'Regione 2': [(np.float64(818.6479988032658),
#        np.float64(0.03296011476250362),
#        np.float64(3.2626486653756754)),
#       (np.float64(829.8243054109447),
#        np.float64(0.3554618665866785),
#        np.float64(4.693983928085842))]}],
#    'emi=2': [{'Regione 1': [(np.float64(727.1469523734903),
#        np.float64(0.04989469118424354),
#        np.float64(7.628144815370395)),
#       (np.float64(776.2058677100781),
#        np.float64(0.6522646918432949),
#        np.float64(18.17909629324505))],
#      'Regione 2': [(np.float64(818.7648857294806),
#        np.float64(0.045665303875552676),
#        np.float64(3.1061674190963955)),
#       (np.float64(829.2892421447987),
#        np.float64(0.6085251577016988),
#        np.float64(5.484460843826659))]}],
#    'emi=2o5': [{'Regione 1': [(np.float64(727.085035258605),
#        np.float64(0.05684801615946388),
#        np.float64(7.70257145459423)),
#       (np.float64(774.0162146198428),
#        np.float64(0.6741031084652225),
#        np.float64(23.99505449161039))],
#      'Regione 2': [(np.float64(818.8961913783752),
#        np.float64(0.0434846583585254),
#        np.float64(3.1406046975137474)),
#       (np.float64(829.5448507941719),
#        np.float64(0.7389365600768242),
#        np.float64(6.6469888419006224))]}],
#    'emi=3': [{'Regione 1': [(np.float64(727.5333964956105),
#        np.float64(0.09965069361099663),
#        np.float64(9.495033343585705))],
#      'Regione 2': [(np.float64(819.5997546554519),
#        np.float64(0.17073389431949626),
#        np.float64(4.241163780036042))]}]},
#   'ass=1': [{'Regione 1': [(np.float64(726.3292451750536),
#       np.float64(0.08441587897758819),
#       np.float64(6.883294649096516)),
#      (np.float64(748.8915513368298),
#       np.float64(0.8209613454461587),
#       np.float64(26.812362057591795))],
#     'Regione 2': [(np.float64(818.3383079654907),
#       np.float64(0.052410918546572455),
#       np.float64(4.444601580569012))]}]}}
